# %%
r"""
    This model primaryly estimates the vertical transport velocity for microplastics
    December 7th, 2021
    Code by Xiangfei Sun, Jinan University

    Please see the associated paper:
    Sun X., Zeng E.Y., Xie M., Mai L., Song X. 
    2022
    Microplastic Deposition in Ocean
    Science
"""

# Functional Package Import
import os 
import numpy as np
import matplotlib.pyplot as plt
import re

reference_dataset_MLH = np.array([[0,25,50,75,100,200,400,600,800,950],[3,4,3,2,5,12,7,9,4,2]])
reference_dataset_SK1 = np.array([[2,50,400,1000],[2,1.2,1.5,1.2]])
reference_dataset_SK2 = np.array([[2,50,200,260,300,500,1000,2000,3000],[1.3,0.9,1.1,0.8,1.5,0.5,0.8,0.5,0.3]])
reference_dataset_SK3 = np.array([[2,50,100,500,1000,2000],[0.3,1.5,0.3,0.7,0.2,0.2]])
reference_dataset_SY1 = np.array([[50,100,200,500,1000],[1.7,1,3.5,1,1.1]]) # 13.5N, 87.3E
reference_dataset_SY2 = np.array([[50,100,200,500,1000],[1.7,1.7,2.3,1.2,0.5]]) # 0.1N, 87.3E
reference_dataset_SY3 = np.array([[50,100,200,500,1000],[0.7,1.1,1.3,0.4,0.2]]) # 13.5S, 87.3E
reference_dataset_EGIV = np.array([[1,303,993,2574],[337,78,16,29]])  #
reference_dataset_N5 = np.array([[3,289,999,2549],[1287,54,53,186]])
reference_dataset_HGIV = np.array([[1,302,974,2449],[218,152,90,0]]) 
reference_dataset_HGIX = np.array([[2,308,1022,2050],[113,38,65,119]]) 
reference_dataset_DP1 = np.array([[50,100,150,200,300,400,500,600],[1.67,1.67,0.83,0.83,0.21,0.42,1.28,0.00]]) 
reference_dataset_DP2 = np.array([[50,100,150,200,300,400,500,600],[5.42,0,0.21,0,0.83,0.21,0.42,0]])

location = [['MLH','36.8N','122.5W'],['SK1','23.2N','127.3E'],['SK2','12.1N','141.8E'],['SK3','14.8N','145.8E']
            ,['SY1','13.5N','87.3E'],['SY2','0.1N','87.3E'],['SY3','13.5S','87.3E'],['DP1','33.7N','40.5W']
            ,['DP2','34.4N','36.2W'],['EGIV','78.8N','2.8E'],['N5','79.9N','3.1W'],['HGIV','79.1N','4.2W']
            ,['HGIX','79.1N','2.8W']]

#SY_2
plt.figure(figsize=(30,12),dpi=400)
grid = plt.GridSpec(6,14,wspace=2,hspace=1.2)
font1 = {'family': 'Arial',
            'weight': 'normal',
            'size': 24,
            }

font2 = {'family': 'Arial',
            'weight': 'normal',
            'size': 24,
            }
    
plt.subplot(grid[0:3,0:2])
title = 'Tropical Indian Ocean'
plt.scatter(reference_dataset_SY2[1],reference_dataset_SY2[0],color='Green')
plt.ylabel('Depth (m)',font2)
plt.title(title,font2)
plt.tick_params(labelsize = 16)
plt.ylim(max(reference_dataset_SY2[0]), min(reference_dataset_SY2[0]))

plt.subplot(grid[0:3,2:4])
title = 'Arctic Ocean'
plt.scatter(reference_dataset_HGIX[1],reference_dataset_HGIX[0],color='Green')
plt.title(title,font2)
plt.tick_params(labelsize = 16)
plt.ylim(max(reference_dataset_HGIX[0]), min(reference_dataset_HGIX[0]))

plt.subplot(grid[0:3,4:6])
title = 'North Atlantic Ocean'
plt.scatter(reference_dataset_DP2[1],reference_dataset_DP2[0],color='Green')
plt.title(title,font2)
plt.tick_params(labelsize = 16)
plt.ylim(max(reference_dataset_DP2[0]), min(reference_dataset_DP2[0]))

plt.subplot(grid[0:3,6:8])
itle = 'South Indian Ocean'
plt.scatter(reference_dataset_SY3[1],reference_dataset_SY3[0],color='Green')
plt.title(title,font2)
plt.tick_params(labelsize = 16)
plt.ylim(max(reference_dataset_SY3[0]), min(reference_dataset_SY3[0]))

plt.subplot(grid[0:3,8:10])
title = 'Arctic Ocean'
plt.scatter(reference_dataset_EGIV[1],reference_dataset_EGIV[0],color='Green')
plt.title(title,font2)
plt.tick_params(labelsize = 16)
plt.ylim(max(reference_dataset_EGIV[0]), min(reference_dataset_EGIV[0]))

plt.subplot(grid[0:3,10:12])
title = 'West Pacific Ocean'
plt.scatter(reference_dataset_MLH[1],reference_dataset_MLH[0],color='Green')
plt.title(title,font2)
plt.tick_params(labelsize = 16)
plt.ylim(max(reference_dataset_MLH[0]), min(reference_dataset_MLH[0]))

plt.subplot(grid[0:3,12:14])
title = 'North Atlantic Ocean'
plt.scatter(reference_dataset_DP1[1],reference_dataset_DP1[0],color='Green')
plt.xlabel('Particles/m\u00b3',font2)
plt.title(title,font2)
plt.tick_params(labelsize = 16)
plt.ylim(max(reference_dataset_DP1[0]), min(reference_dataset_DP1[0]))

plt.subplot(grid[3:6,0:2])
title = 'North Pacific Ocean'
plt.scatter(reference_dataset_SK1[1],reference_dataset_SK1[0],color='Green')
plt.ylabel('Depth (m)',font2)
plt.xlabel('Particles/m\u00b3',font2)
plt.title(title,font2)
plt.tick_params(labelsize = 16)
plt.ylim(max(reference_dataset_SK1[0]), min(reference_dataset_SK1[0]))

plt.subplot(grid[3:6,2:4])
title = 'Arctic Ocean'
plt.scatter(reference_dataset_HGIV[1],reference_dataset_HGIV[0],color='Green')
plt.xlabel('Particles/m\u00b3',font2)
plt.title(title,font2)
plt.tick_params(labelsize = 16)
plt.ylim(max(reference_dataset_HGIV[0]), min(reference_dataset_HGIV[0]))

plt.subplot(grid[3:6,4:6])
title = 'Tropical Pacific Ocean'
plt.scatter(reference_dataset_SK3[1],reference_dataset_SK3[0],color='Green')
plt.xlabel('Particles/m\u00b3',font2)
plt.title(title,font2)
plt.tick_params(labelsize = 16)
plt.ylim(max(reference_dataset_SK3[0]), min(reference_dataset_SK3[0]))

plt.subplot(grid[3:6,6:8])
title = 'Arctic Ocean'
plt.scatter(reference_dataset_N5[1],reference_dataset_N5[0],color='Green')
plt.title(title,font2)
plt.xlabel('Particles/m\u00b3',font2)
plt.tick_params(labelsize = 16)
plt.ylim(max(reference_dataset_N5[0]), min(reference_dataset_N5[0]))

plt.subplot(grid[3:6,8:10])
title = 'East Pacific Ocean'
plt.scatter(reference_dataset_SK2[1],reference_dataset_SK2[0],color='Green')
plt.xlabel('Particles/m\u00b3',font2)
plt.title(title,font2)
plt.tick_params(labelsize = 16)
plt.ylim(max(reference_dataset_SK2[0]), min(reference_dataset_SK2[0]))

plt.subplot(grid[3:6,10:12])
title = 'North Indian Ocean'
plt.scatter(reference_dataset_SY1[1],reference_dataset_SY1[0],color='Green')
plt.xlabel('Particles/m\u00b3',font2)
plt.title(title,font2)
plt.tick_params(labelsize = 16)
plt.ylim(max(reference_dataset_SY1[0]), min(reference_dataset_SY1[0]))
# Out:
# (1000.0, 50.0)
